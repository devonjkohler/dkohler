# %% [markdown]
# # Analysis of New Data - https://data.world/dataquest/mlb-game-logs

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('..\..\..\MLB\MLB_Data.csv', parse_dates = ['date'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (12,13,14,15,19,20,81,83,85,87,93,94,95,96,97,98,99,100,105,106,108,109,111,112,114,115,117,118,120,121,123,124,126,127,129,130,132,133,135,136,138,139,141,142,144,145,147,148,150,151,153,154,156,157,160) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.tail()
# Out:
#              date  number_of_game day_of_week v_name v_league  v_game_number  \
# 171902 2016-10-02               0         Sun    MIL       NL            162
# 171903 2016-10-02               0         Sun    NYN       NL            162
# 171904 2016-10-02               0         Sun    LAN       NL            162
# 171905 2016-10-02               0         Sun    PIT       NL            162
# 171906 2016-10-02               0         Sun    MIA       NL            161
#
#        h_name h_league  h_game_number  v_score  ...  h_player_7_name  \
# 171902    COL       NL            162        6  ...      Pat Valaika
# 171903    PHI       NL            162        2  ...    Andres Blanco
# 171904    SFN       NL            162        1  ...        Joe Panik
# 171905    SLN       NL            162        4  ...      Jedd Gyorko
# 171906    WAS       NL            162        7  ...   Danny Espinosa
#
#         h_player_7_def_pos h_player_8_id   h_player_8_name h_player_8_def_pos  \
# ...
